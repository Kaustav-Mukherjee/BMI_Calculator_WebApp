# %% [markdown]
# #BMI CALCULATOR

# %% [markdown]
# #BMI = (weight in pounds x 703) / (height in inches x height in inches)

# %% [markdown]
# Under 18.5	Underweight	Minimal
# 18.5 - 24.9	Normal Weight	Minimal
# 25 - 29.9	Overweight	Increased
# 30 - 34.9	Obese	High
# 35 - 39.9	Severely Obese	Very High
# 40 and over	Morbidly Obese	Extremely High

# %% [markdown]
# #TOTAL CODE

# %%
name = input("Enter your name: ")
weight = int(input("Enter your weight in pounds: "))
height = int(input("Enter your height in inches: "))
BMI = (weight * 703) / (height * height)
print("Your BMI is: " , BMI)

if BMI>0:
    if(BMI<18.5):
        print(name + ", You are underweight.")
    elif(BMI<24.9):
        print(name + ", You are Normal weight.")
    elif(BMI<29.9):
        print(name + ", You are Overweight.")
    elif(BMI<34.9):
        print(name + ", You are Obese.")
    elif(BMI<39.9):
        print(name + ", You are Severely Obsese.")
    else:
        print(name + ", You are Morbidly Obsese.")
else:
    print("Enter Valid Inputs")
# Out:
# Enter your name:  Kaustav
# Enter your weight in pounds:  154
# Enter your height in inches:  69
# Your BMI is:  22.73934047469019
# Kaustav, You are Normal weight.

# %% [markdown]
# #CALCULATION

# %%
weight = input("Enter your weight in pounds: ")
height = input("Enter your height in inches: ")
BMI = (weight * 703) / (height * height)
# Out:
# Enter your weight in pounds:  170
# Enter your height in inches:  69
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 weight = input("Enter your weight in pounds: ")
#       2 height = input("Enter your height in inches: ")
# ----> 3 BMI = (weight * 703) / (height * height)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %% [markdown]
# ##FIX:

# %%
name = input("Enter your name: ")
weight = int(input("Enter your weight in pounds: "))
height = int(input("Enter your height in inches: "))
BMI = (weight * 703) / (height * height)
print(BMI)
# Out:
# Enter your name:  Kausty
# Enter your weight in pounds:  154
# Enter your height in inches:  69
# 22.73934047469019

# %% [markdown]
# #GIVING A CLASSIFICATION TO USER

# %%
if BMI>0:
    if(BMI<18.5):
        print(name + ", You are underweight.")
    elif(BMI<24.9):
        print(name + ", You are Normal weight.")
    elif(BMI<29.9):
        print(name + ", You are Overweight.")
    elif(BMI<34.9):
        print(name + ", You are Obese.")
    elif(BMI<39.9):
        print(name + ", You are Severely Obsese.")
    else:
        print(name + ", You are Morbidly Obsese.")
else:
    print("Enter Valid Inputs")
# Out:
# Kausty, You are Normal weight.
